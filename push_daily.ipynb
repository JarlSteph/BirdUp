# %%
from Features.df_functions import *
from hsfs.feature import Feature
import datetime
import requests
import pandas as pd
import hopsworks
import json
import re
import os
import warnings
warnings.filterwarnings("ignore")
from dotenv import load_dotenv
load_dotenv()

HOPSWORKS_API_KEY = os.getenv("HOPSWORKS_API_KEY")
project = hopsworks.login(api_key_value=HOPSWORKS_API_KEY, project="BirdUp")
fs = project.get_feature_store(name='birdup_featurestore')

def insert_daily_data():
    # retrive todays data: 
    birding_fg = fs.get_feature_group(name='birding',version=1,)
    print(birding_fg)
    daily_df = daily()
    daily_df = to_hopsworks_df(daily_df)
    birding_fg.insert(daily_df, wait=True)
    return
insert_daily_data()
# Out:
# 2025-12-19 10:39:12,628 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2025-12-19 10:39:12,631 INFO: Initializing external client
# 2025-12-19 10:39:12,631 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-12-19 10:39:14,459 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1327256
# <hsfs.feature_group.FeatureGroup object at 0x1766b1eb0>
# 2025-12-19 10:39:23,510 INFO: 	4 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1327256/fs/1315910/fg/1869174
# Uploading Dataframe: 100.00% |██████████| Rows 50/50 | Elapsed Time: 00:01 | Remaining Time: 00:00
# %6|1766137174.512|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50393ms in state UP, 1 identical error(s) suppressed)
# %6|1766137225.508|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 50343ms in state UP, 1 identical error(s) suppressed)
# %6|1766137276.629|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50202ms in state UP, 1 identical error(s) suppressed)
# %6|1766137327.680|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50126ms in state UP, 1 identical error(s) suppressed)
# %6|1766137423.343|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.81.188:9093/bootstrap]: ssl://51.161.81.188:9093/1: Disconnected (after 94619ms in state UP, 1 identical error(s) suppressed)
# %6|1766137474.242|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.81.208:9093/bootstrap]: ssl://51.161.81.208:9093/2: Disconnected (after 50202ms in state UP, 1 identical error(s) suppressed)
# %6|1766137525.641|FAIL|rdkafka#producer-1| [thrd:ssl://51.161.80.189:9093/bootstrap]: ssl://51.161.80.189:9093/0: Disconnected (after 50397ms in state UP, 1 identical error(s) suppressed)
