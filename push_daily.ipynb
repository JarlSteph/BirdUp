# %%
from Features.df_functions import *
from hsfs.feature import Feature
import datetime
import requests
import pandas as pd
import hopsworks
import json
import re
import os
import warnings
warnings.filterwarnings("ignore")
from dotenv import load_dotenv
load_dotenv()

HOPSWORKS_API_KEY = os.getenv("HOPSWORKS_API_KEY")
project = hopsworks.login(api_key_value=HOPSWORKS_API_KEY, project="BirdUp")
fs = project.get_feature_store(name='birdup_featurestore')

def insert_daily_data():
    # retrive todays data: 
    birding_fg = fs.get_feature_group(name='birding',version=1,)
    print(birding_fg)
    daily_df = daily()
    df_prev = birding_fg.read()
    daily_df = to_hopsworks_df(daily_df)
    day_df_lag = add_daily_lags_from_hopsworks_simple(daily_df, df_prev, k=5)
    birding_fg.insert(day_df_lag, wait=True)
    return
insert_daily_data()
# Out:
# 2025-12-19 13:20:05,954 INFO: Initializing external client
# 2025-12-19 13:20:05,954 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-12-19 13:20:08,820 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1327256
# <hsfs.feature_group.FeatureGroup object at 0x174ad38f0>
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (10.13s)
# 2025-12-19 13:20:32,349 INFO: 	4 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1327256/fs/1315910/fg/1867169
# Uploading Dataframe: 100.00% |██████████| Rows 50/50 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: birding_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1327256/jobs/named/birding_1_offline_fg_materialization/executions
# 2025-12-19 13:20:50,663 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-12-19 13:20:53,853 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-12-19 13:22:52,542 INFO: Waiting for execution to finish. Current state: SUCCEEDING. Final status: UNDEFINED
# 2025-12-19 13:22:55,789 INFO: Waiting for execution to finish. Current state: FINISHED. Final status: SUCCEEDED
# 2025-12-19 13:22:56,444 INFO: Waiting for log aggregation to finish.
# 2025-12-19 13:22:56,445 INFO: Execution finished successfully.
